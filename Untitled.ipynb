# %%
import numpy as np

# %%
arr = np.array([1,2,3])

# %%
arr.mean()
# Out:
# np.float64(2.0)

# %%
arr.max()
# Out:
# np.int64(3)

# %%
arr.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 arr.shape()
#
# TypeError: 'tuple' object is not callable

# %%
arr.nonzero()
# Out:
# (array([0, 1, 2]),)

# %%
arr.partition(2)

# %%
arr
# Out:
# array([1, 2, 3])

# %%
import pandas as pd

# %%
# !ls
# Out:
# flie.csv  Untitled3.ipynb  Untitled.ipynb  venv

# %%
df = pd.read_csv("flie.csv")

# %%
df
# Out:
#    id         name              email    role    status
# 0   1   Raj Sharma    raj.s@email.com   Admin    Active
# 1   2  Priya Singh  priya.s@email.com  Editor    Active
# 2   3   Amit Patel  a.patel@email.com  Viewer  Inactive
# 3   4   Neha Gupta  n.gupta@email.com  Editor    Active

# %%
df.columns
# Out:
# Index(['id', 'name', 'email', 'role', 'status'], dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.head()
# Out:
#    id         name              email    role    status
# 0   1   Raj Sharma    raj.s@email.com   Admin    Active
# 1   2  Priya Singh  priya.s@email.com  Editor    Active
# 2   3   Amit Patel  a.patel@email.com  Viewer  Inactive
# 3   4   Neha Gupta  n.gupta@email.com  Editor    Active

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      int64
#  1   name    4 non-null      str
#  2   email   4 non-null      str
#  3   role    4 non-null      str
#  4   status  4 non-null      str
# dtypes: int64(1), str(4)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#              id
# count  4.000000
# mean   2.500000
# std    1.290994
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    4.000000

# %%
for i in df.groupby(sort=True,by="name"):
    print(i,)
    print()
# Out:
# ('Amit Patel',    id        name              email    role    status
# 2   3  Amit Patel  a.patel@email.com  Viewer  Inactive)
#
# ('Neha Gupta',    id        name              email    role  status
# 3   4  Neha Gupta  n.gupta@email.com  Editor  Active)
#
# ('Priya Singh',    id         name              email    role  status
# 1   2  Priya Singh  priya.s@email.com  Editor  Active)
#
# ('Raj Sharma',    id        name            email   role  status
# 0   1  Raj Sharma  raj.s@email.com  Admin  Active)

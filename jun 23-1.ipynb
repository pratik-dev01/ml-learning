# %%
import pandas as pd

# %% [markdown]
# ### learning the train test split

# %%
df = pd.DataFrame({
    "Age":[20,22,25,27,30,32,35,38],
    "Salary":[30000,35000,45000,50000,60000,65000,70000,80000],
    "Purchased":[0,0,1,0,1,1,1,1]
})

# %%
df
# Out:
#    Age  Salary  Purchased
# 0   20   30000          0
# 1   22   35000          0
# 2   25   45000          1
# 3   27   50000          0
# 4   30   60000          1
# 5   32   65000          1
# 6   35   70000          1
# 7   38   80000          1

# %%
# !sklearn
# Out:
# /bin/bash: line 1: sklearn: command not found

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 384.5 kB/s eta 0:00:00 kB/s eta 0:00:01
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached narwhals-2.22.1-py3-none-any.whl (454 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 5.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
X = df['Purchased']

# %%
X
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# 5    1
# 6    1
# 7    1
# Name: Purchased, dtype: int64

# %%
y = df.drop('Purchased',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=54)

# %%
X_test
# Out:
# 6    1
# 4    1
# Name: Purchased, dtype: int64

# %%
X_train
# Out:
# 3    0
# 0    0
# 1    0
# 2    1
# 5    1
# 7    1
# Name: Purchased, dtype: int64
